# %% [markdown]
# <a href="https://colab.research.google.com/github/julozanoa/AlgorithmsUN2021II/blob/main/Lab13/(Group1)AlgorithmicToolboxWeek3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programming Assignment 3: Greedy Algorithms
#
# ##1 Money Change
# ###Problem Introduction
# In this problem, you will design and implement an elementary greedy algorithm
# used by cashiers all over the world millions of times per day![image.png](data:image/png;base64,...)
#
#
# ###Problem Description
# **Task**. The goal in this problem is to find the minimum number of coins needed to change the input value
# (an integer) into coins with denominations 1, 5, and 10.
#
# **Input Format.** The input consists of a single integer 𝑚.
# **Constraints**. 1 ≤ 𝑚 ≤ 103.
#
# **Output Format.** Output the minimum number of coins with denominations 1, 5, 10 that changes 𝑚.

# %% [markdown]
# **Sample 1.**
#
# Input:
#
# 2
#
# Output:
#
# 2
#
# 2 = 1 + 1.

# %%
n = int(input())
count = 0
for i in [10, 5, 1]:
    if n>=i:
        q = n//i
        count += q
        n = n%i
        if n==0:
            print(count)
            quit()
# Out:
# 2
# 2

# %% [markdown]
# **Sample 2.**
#
# Input:
#
# 28
#
# Output:
#
# 6
#
# 28 = 10 + 10 + 5 + 1 + 1 + 1.

# %%
n = int(input())
count = 0
for i in [10, 5, 1]:
    if n>=i:
        q = n//i
        count += q
        n = n%i
        if n==0:
            print(count)
            quit()
# Out:
# 28
# 6

# %% [markdown]
# ![imagen_2022-02-05_204923.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2022-02-05_205124.png](data:image/png;base64,...)

# %%
n, W = [int(i) for i in input().split()]
lst = []

if W == 0:
    print(0)
    quit()

for _ in range(n):
    v, w = [int(i) for i in input().split()]
    if v == 0:
        continue
    lst.append((v, w))

lst.sort(key = lambda x: x[0]/x[1], reverse = True)

total_value = 0

for v,w in lst:
    if W==0:
        print(total_value)
        quit()
    amt = min(w, W)
    total_value += amt*v/w
    W -= amt

print(total_value)
# Out:
# 3 50
# 60 20
# 100 50
# 120 30
# 180.0
# 180.0

# %% [markdown]
# ![imagen_2022-02-05_205339.png](data:image/png;base64,...)

# %%
n, W = [int(i) for i in input().split()]
lst = []

if W == 0:
    print(0)
    quit()

for _ in range(n):
    v, w = [int(i) for i in input().split()]
    if v == 0:
        continue
    lst.append((v, w))

lst.sort(key = lambda x: x[0]/x[1], reverse = True)

total_value = 0

for v,w in lst:
    if W==0:
        print(total_value)
        quit()
    amt = min(w, W)
    total_value += amt*v/w
    W -= amt

print(total_value)
# Out:
# 1 10
# 500 30
# 166.66666666666666

# %% [markdown]
# ![imagen_2022-02-05_205537.png](data:image/png;base64,...)

# %% [markdown]
#  ![imagen_2022-02-05_205718.png](data:image/png;base64,...)

# %%
n = int(input())
a = [int(i) for i in input().split()]
b = [int(i) for i in input().split()]
a.sort()
b.sort()
ans = sum([a[i]*b[i] for i in range(n)])
print(ans)
# Out:
# 1
# 23
# 39
# 897

# %% [markdown]
# ![imagen_2022-02-05_205741.png](data:image/png;base64,...)

# %%
n = int(input())
a = [int(i) for i in input().split()]
b = [int(i) for i in input().split()]
a.sort()
b.sort()
ans = sum([a[i]*b[i] for i in range(n)])
print(ans)
# Out:
# 3
# 1 3 -5
# -2 4 1
# 23

# %% [markdown]
# ![imagen_2022-02-05_210038.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2022-02-05_210143.png](data:image/png;base64,...)

# %%
n = int(input())
lst = []

for _ in range(n):
    a, b = [int(i) for i in input().split()]
    lst.append((a,b))

lst.sort(key = lambda x: x[1])

index = 0
coordinates = []

while index < n:
    curr = lst[index]
    while index < n-1 and curr[1]>=lst[index+1][0]:
        index += 1
    coordinates.append(curr[1])
    index += 1
print(len(coordinates))
print(' '.join([str(i) for i in coordinates]))
# Out:
# 3
# 1 3
# 2 5
# 3 6
# 1
# 3

# %% [markdown]
# ![imagen_2022-02-05_210223.png](data:image/png;base64,...)

# %%
n = int(input())
lst = []

for _ in range(n):
    a, b = [int(i) for i in input().split()]
    lst.append((a,b))

lst.sort(key = lambda x: x[1])

index = 0
coordinates = []

while index < n:
    curr = lst[index]
    while index < n-1 and curr[1]>=lst[index+1][0]:
        index += 1
    coordinates.append(curr[1])
    index += 1
print(len(coordinates))
print(' '.join([str(i) for i in coordinates]))
# Out:
# 4
# 4 7
# 1 3
# 2 5
# 5 6
# 2
# 3 6

# %% [markdown]
# ![imagen_2022-02-05_210343.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2022-02-05_210510.png](data:image/png;base64,...)

# %%
n = int(input())
if n == 1:
    print(1)
    print(1)
    quit()
W = n
prizes = []
for i in range(1, n):
    if W>2*i:
        prizes.append(i)
        W -= i
    else:
        prizes.append(W)
        break

print(len(prizes))
print(' '.join([str(i) for i in prizes]))
# Out:
# 6
# 3
# 1 2 3

# %% [markdown]
# ![imagen_2022-02-05_210541.png](data:image/png;base64,...)

# %%
n = int(input())
if n == 1:
    print(1)
    print(1)
    quit()
W = n
prizes = []
for i in range(1, n):
    if W>2*i:
        prizes.append(i)
        W -= i
    else:
        prizes.append(W)
        break

print(len(prizes))
print(' '.join([str(i) for i in prizes]))
# Out:
# 8
# 3
# 1 2 5

# %% [markdown]
# ![imagen_2022-02-05_210751.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2022-02-05_210833.png](data:image/png;base64,...)

# %%
n = int(input())
lst = [int(i) for i in input().split()]


def IsGreaterOrEqual(digit, max_digit):
    return int(str(digit)+str(max_digit))>=int(str(max_digit)+str(digit))

def largestnumber(lst):
    answer = []
    
    while lst!=[]:
        max_digit = 0
        for digit in lst:
            if IsGreaterOrEqual(digit, max_digit):
                max_digit = digit
        answer.append(max_digit)
        lst.remove(max_digit)

    return answer

print(''.join([str(i) for i in largestnumber(lst)]))
# Out:
# 2
# 21 2
# 221

# %% [markdown]
# ![imagen_2022-02-05_211038.png](data:image/png;base64,...)

# %%
n = int(input())
lst = [int(i) for i in input().split()]


def IsGreaterOrEqual(digit, max_digit):
    return int(str(digit)+str(max_digit))>=int(str(max_digit)+str(digit))

def largestnumber(lst):
    answer = []
    
    while lst!=[]:
        max_digit = 0
        for digit in lst:
            if IsGreaterOrEqual(digit, max_digit):
                max_digit = digit
        answer.append(max_digit)
        lst.remove(max_digit)

    return answer

print(''.join([str(i) for i in largestnumber(lst)]))
# Out:
# 5
# 9 4 6 1 9
# 99641

# %% [markdown]
# #Comprobantes Coursera

# %% [markdown]
# ## Santiago Acosta Artunduaga

# %% [markdown]
# ![imagen_2022-02-05_215228.png](data:image/png;base64,...)

# %% [markdown]
# ## Juan Pablo Lozano Aranguren

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Brian Chaparro Cetina

# %% [markdown]
# ![Week3_BrianChaparroCetina.png](data:image/png;base64,...)
